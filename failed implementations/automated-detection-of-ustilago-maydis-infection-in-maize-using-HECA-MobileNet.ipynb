# %%
# !pip install tensorflow scikit-learn matplotlib seaborn opencv-python streamlit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 55.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 67.6 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/abolfazlkeshavarz/Classification-of-plant-infection.git
# !find Classification-of-plant-infection -maxdepth 3 -type d
# Out:
# fatal: destination path 'Classification-of-plant-infection' already exists and is not an empty directory.
# Classification-of-plant-infection
# Classification-of-plant-infection/.git
# Classification-of-plant-infection/.git/info
# Classification-of-plant-infection/.git/hooks
# Classification-of-plant-infection/.git/logs
# Classification-of-plant-infection/.git/logs/refs
# Classification-of-plant-infection/.git/objects
# Classification-of-plant-infection/.git/objects/pack
# Classification-of-plant-infection/.git/objects/info
# Classification-of-plant-infection/.git/refs
# Classification-of-plant-infection/.git/refs/remotes
# Classification-of-plant-infection/.git/refs/heads
# Classification-of-plant-infection/.git/refs/tags
# Classification-of-plant-infection/.git/branches

# %%
# !ls
# !ls classification-of-plant-infection
# Out:
# Classification-of-plant-infection    sample_data
# Plant-Scanner-THM-Marburg-MaizeLeaf
# ls: cannot access 'classification-of-plant-infection': No such file or directory

# %%
# !find classification-of-plant-infection -maxdepth 2 -type f
# Out:
# find: ‘classification-of-plant-infection’: No such file or directory

# %%
# !ls Classification-of-plant-infection
# Out:
# Infected.ipynb	README.md

# %%
# !find Classification-of-plant-infection -maxdepth 2 -type f
# Out:
# Classification-of-plant-infection/Infected.ipynb
# Classification-of-plant-infection/README.md
# Classification-of-plant-infection/.git/index
# Classification-of-plant-infection/.git/config
# Classification-of-plant-infection/.git/packed-refs
# Classification-of-plant-infection/.git/HEAD
# Classification-of-plant-infection/.git/description

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras import layers, models
from tensorflow.keras.applications import MobileNetV3Small

IMG_SIZE = (224, 224)
BATCH = 32

train_ds = image_dataset_from_directory(
    "dataset",
    validation_split=0.2,
    subset="training",
    seed=42,
    image_size=IMG_SIZE,
    batch_size=BATCH
)

val_ds = image_dataset_from_directory(
    "dataset",
    validation_split=0.2,
    subset="validation",
    seed=42,
    image_size=IMG_SIZE,
    batch_size=BATCH
)

classes = train_ds.class_names
print(classes)

base = MobileNetV3Small(
    input_shape=(224,224,3),
    include_top=False,
    weights="imagenet"
)
base.trainable = False

model = models.Sequential([
    layers.Rescaling(1./255),
    base,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation="relu"),
    layers.Dropout(0.3),
    layers.Dense(len(classes), activation="softmax")
])

model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

history = model.fit(train_ds, validation_data=val_ds, epochs=10)
model.save("baseline.keras")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_15627/2648342865.py in <cell line: 0>()
#       7 BATCH = 32
#       8
# ----> 9 train_ds = image_dataset_from_directory(
#      10     "dataset",
#      11     validation_split=0.2,
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/image_dataset_utils.py in image_dataset_from_directory(directory, labels, label_mode, class_names, color_mode, batch_size, image_size, shuffle, seed, validation_split, subset, interpolation, follow_links, crop_to_aspect_ratio, pad_to_aspect_ratio, data_format, format, verbose)
#     263     if seed is None:
#     264         seed = np.random.randint(1e6)
# --> 265     image_paths, labels, class_names = dataset_utils.index_directory(
#     266         directory,
#     267         labels,
#
# ...
