# %%
import kagglehub
import os

TOMATO_ROOT = kagglehub.dataset_download(
    "yusufmurtaza01/tomato-leaf-disease"
)

yaml_path = None

for root, dirs, files in os.walk(TOMATO_ROOT):
    if "data.yaml" in files:
        yaml_path = os.path.join(root, "data.yaml")
        break

print("Dataset:", TOMATO_ROOT)
print("YAML:", yaml_path)
# Out:
# Downloading to /root/.cache/kagglehub/datasets/yusufmurtaza01/tomato-leaf-disease/2.archive...
# 100%|██████████| 445M/445M [00:05<00:00, 85.2MB/s]
# Extracting files...
# Dataset: /root/.cache/kagglehub/datasets/yusufmurtaza01/tomato-leaf-disease/versions/2
# YAML: /root/.cache/kagglehub/datasets/yusufmurtaza01/tomato-leaf-disease/versions/2/tomato/data.yaml

# %%
import kagglehub
import os
import yaml

TOMATO_ROOT = kagglehub.dataset_download(
    "yusufmurtaza01/tomato-leaf-disease"
)

yaml_path = None

for root, dirs, files in os.walk(TOMATO_ROOT):
    if "data.yaml" in files:
        yaml_path = os.path.join(root, "data.yaml")
        break

with open(yaml_path, "r") as f:
    data = yaml.safe_load(f)

CLASS_NAMES = data["names"]

print("Dataset:", TOMATO_ROOT)
print("YAML:", yaml_path)
print("Classes:", len(CLASS_NAMES))
# Out:
# Dataset: /root/.cache/kagglehub/datasets/yusufmurtaza01/tomato-leaf-disease/versions/2
# YAML: /root/.cache/kagglehub/datasets/yusufmurtaza01/tomato-leaf-disease/versions/2/tomato/data.yaml
# Classes: 10

# %%
ROOT = os.path.dirname(yaml_path)

IMG_TRAIN = os.path.join(ROOT, "images/train")
IMG_VAL = os.path.join(ROOT, "images/val")

LBL_TRAIN = os.path.join(ROOT, "labels/train")
LBL_VAL = os.path.join(ROOT, "labels/val")

print(IMG_TRAIN)
print(LBL_TRAIN)
# Out:
# /root/.cache/kagglehub/datasets/yusufmurtaza01/tomato-leaf-disease/versions/2/tomato/images/train
# /root/.cache/kagglehub/datasets/yusufmurtaza01/tomato-leaf-disease/versions/2/tomato/labels/train

# %%
model.save("/kaggle/working/tomato_baseline.keras")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_6693/2702336540.py in <cell line: 0>()
# ----> 1 model.save("/kaggle/working/tomato_baseline.keras")
#
# NameError: name 'model' is not defined
