# %%
import kagglehub
import os

path = kagglehub.dataset_download(
    "yusufmurtaza01/tomato-leaf-disease"
)

print("Returned path:", path)

for root, dirs, files in os.walk(path):
    if "data.yaml" in files:
        print("FOUND:", os.path.join(root, "data.yaml"))
# Out:
# Using Colab cache for faster access to the 'tomato-leaf-disease' dataset.
# Returned path: /kaggle/input/tomato-leaf-disease
# FOUND: /kaggle/input/tomato-leaf-disease/tomato/data.yaml

# %%
import os

for root, dirs, files in os.walk(path):
    print(root)
    if "data.yaml" in files:
        print("FOUND DATA.YAML:", os.path.join(root, "data.yaml"))
# Out:
# /kaggle/input/tomato-leaf-disease
# /kaggle/input/tomato-leaf-disease/tomato
# FOUND DATA.YAML: /kaggle/input/tomato-leaf-disease/tomato/data.yaml
# /kaggle/input/tomato-leaf-disease/tomato/labels
# /kaggle/input/tomato-leaf-disease/tomato/labels/val
# /kaggle/input/tomato-leaf-disease/tomato/labels/train
# /kaggle/input/tomato-leaf-disease/tomato/images
# /kaggle/input/tomato-leaf-disease/tomato/images/val
# /kaggle/input/tomato-leaf-disease/tomato/images/train

# %%
print("Returned:", path)
print("Exists:", os.path.exists(path))
# Out:
# Returned: /kaggle/input/tomato-leaf-disease
# Exists: True

# %%
import os

for root, dirs, files in os.walk("/kaggle/input/tomato-leaf-disease"):
    if "data.yaml" in files:
        print(os.path.join(root, "data.yaml"))
# Out:
# /kaggle/input/tomato-leaf-disease/tomato/data.yaml

# %%
import yaml

yaml_path = "/kaggle/input/tomato-leaf-disease/tomato/data.yaml"

with open(yaml_path, "r") as f:
    data = yaml.safe_load(f)

print(data)
# Out:
# {'path': '/kaggle/input/datasets/yusufmurtaza01/tomato-leaf-disease/tomato', 'train': 'images/train', 'val': 'images/val', 'test': '', 'nc': 10, 'names': ['Tomato__BacterialSpot', 'Tomato__EarlyBlight', 'Tomato__Healthy', 'Tomato__LateBlight', 'Tomato__LeafMold', 'Tomato__MosaicVirus', 'Tomato__SeptoriaLeafSpot', 'Tomato__SpiderMites', 'Tomato__TargetSpot', 'Tomato__YellowLeafCurlVirus']}
