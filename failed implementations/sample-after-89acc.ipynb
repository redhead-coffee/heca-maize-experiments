# %%
import kagglehub

tomato_path = kagglehub.dataset_download(
    "yusufmurtaza01/tomato-leaf-disease"
)

print(tomato_path)
# Out:
# ...
# 100%|██████████| 445M/445M [00:03<00:00, 118MB/s]
# Extracting files...
# /root/.cache/kagglehub/datasets/yusufmurtaza01/tomato-leaf-disease/versions/2
